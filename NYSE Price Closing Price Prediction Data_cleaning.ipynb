# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('prices-split-adjusted.csv')

# %%
df.head()
# Out:
#          date symbol        open       close         low        high  \
# 0  2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000
# 1  2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001
# 2  2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998
# 3  2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002
# 4  2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002
#
#       volume
# 0  2163600.0
# 1  2386400.0
# 2  2489500.0
# 3  2006300.0
# 4  1408600.0

# %%
df.shape
# Out:
# (851264, 7)

# %%
df.symbol.value_counts()
# Out:
# NRG     1762
# FIS     1762
# XL      1762
# RTN     1762
# ISRG    1762
# BA      1762
# DAL     1762
# BMY     1762
# HRS     1762
# CXO     1762
# NTAP    1762
# EXPE    1762
# TGT     1762
# MRO     1762
# JEC     1762
# NUE     1762
# GPC     1762
# WAT     1762
# FTR     1762
# REGN    1762
# CNC     1762
# CERN    1762
# HIG     1762
# TXN     1762
# WMB     1762
# UAA     1762
# TGNA    1762
# SRE     1762
# GE      1762
# TSO     1762
#         ...
# KMI     1008
# XYL     1008
# PSX     1008
# DLPH    1008
# NLSN    1008
# KORS    1008
# ABBV    1008
# TDG     1008
# HCA     1008
# FBHS    1008
# MPC     1008
# TRIP    1008
# ZTS      987
# COTY     896
# MNK      894
# NWS      892
# NWSA     892
# EVHC     853
# ALLE     786
# NAVI     504
# CFG      504
# QRVO     504
# SYF      504
# WRK      385
# KHC      378
# PYPL     378
# HPE      304
# CSRA     284
# WLTW     251
# FTV      126
# Name: symbol, Length: 501, dtype: int64

# %%
df.symbol.unique()
# Out:
# array(['WLTW', 'A', 'AAL', 'AAP', 'AAPL', 'ABC', 'ABT', 'ACN', 'ADBE',
#        'ADI', 'ADM', 'ADP', 'ADS', 'ADSK', 'AEE', 'AEP', 'AES', 'AET',
#        'AFL', 'AGN', 'AIG', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALK', 'ALL',
#        'ALXN', 'AMAT', 'AME', 'AMG', 'AMGN', 'AMP', 'AMT', 'AMZN', 'AN',
#        'ANTM', 'AON', 'APA', 'APC', 'APD', 'APH', 'ARNC', 'ATVI', 'AVB',
#        'AVGO', 'AVY', 'AWK', 'AXP', 'AYI', 'AZO', 'BA', 'BAC', 'BAX',
#        'BBBY', 'BBT', 'BBY', 'BCR', 'BDX', 'BEN', 'BHI', 'BIIB', 'BK',
#        'BLK', 'BLL', 'BMY', 'BSX', 'BWA', 'BXP', 'C', 'CA', 'CAG', 'CAH',
#        'CAT', 'CB', 'CBG', 'CBS', 'CCI', 'CCL', 'CELG', 'CERN', 'CF',
#        'CHD', 'CHK', 'CHRW', 'CI', 'CINF', 'CL', 'CLX', 'CMA', 'CMCSA',
#        'CME', 'CMG', 'CMI', 'CMS', 'CNC', 'CNP', 'COF', 'COG', 'COH',
#        'COL', 'COO', 'COP', 'COST', 'CPB', 'CRM', 'CSCO', 'CSX', 'CTAS',
#        'CTL', 'CTSH', 'CTXS', 'CVS', 'CVX', 'CXO', 'D', 'DAL', 'DD', 'DE',
# ...

# %%
df_yahoo = df[df['symbol'] == 'YHOO']

# %%
df_yahoo.head(10)
# Out:
#             date symbol       open      close        low       high  \
# 713   2010-01-04   YHOO  16.940001  17.100000  16.879999  17.200001
# 1181  2010-01-05   YHOO  17.219999  17.230000  17.000000  17.230000
# 1649  2010-01-06   YHOO  17.170000  17.170000  17.070000  17.299999
# 2117  2010-01-07   YHOO  16.809999  16.700001  16.570000  16.900000
# 2585  2010-01-08   YHOO  16.680000  16.700001  16.620001  16.760000
# 3053  2010-01-11   YHOO  16.770000  16.740000  16.480000  16.830000
# 3521  2010-01-12   YHOO  16.650000  16.680000  16.600000  16.860001
# 3989  2010-01-13   YHOO  16.879999  16.900000  16.650000  16.980000
# 4457  2010-01-14   YHOO  16.809999  17.120001  16.799999  17.230000
# 4925  2010-01-15   YHOO  17.250000  16.820000  16.750000  17.250000
#
#           volume
# 713   16587400.0
# 1181  11718100.0
# 1649  16422000.0
# 2117  31816300.0
# 2585  15470000.0
# 3053  16181900.0
# 3521  15672400.0
# 3989  16955600.0
# 4457  16715600.0
# 4925  18415000.0

# %%
df_yahoo.shape
# Out:
# (1762, 7)

# %%
df_yahoo.describe()
# Out:
#               open        close          low         high        volume
# count  1762.000000  1762.000000  1762.000000  1762.000000  1.762000e+03
# mean     27.297917    27.291992    26.975602    27.609977  1.996907e+07
# std      11.412612    11.406846    11.289736    11.526101  1.376851e+07
# min      11.300000    11.090000    11.090000    11.800000  2.586900e+06
# 25%      15.950000    15.920000    15.770000    16.110001  1.235152e+07
# 50%      26.770001    26.750000    26.495000    27.105001  1.639070e+07
# 75%      37.335000    37.377501    36.897501    37.689999  2.325988e+07
# max      52.279999    52.369999    51.639999    52.619999  2.338721e+08

# %%
df_yahoo.corr()
# Out:
#             open     close       low      high    volume
# open    1.000000  0.999184  0.999524  0.999658 -0.168902
# close   0.999184  1.000000  0.999663  0.999646 -0.172272
# low     0.999524  0.999663  1.000000  0.999498 -0.180518
# high    0.999658  0.999646  0.999498  1.000000 -0.162580
# volume -0.168902 -0.172272 -0.180518 -0.162580  1.000000

# %%
df_yahoo.isnull().sum()
# Out:
# date      0
# symbol    0
# open      0
# close     0
# low       0
# high      0
# volume    0
# dtype: int64

# %%
df['date'].dtype
# Out:
# dtype('O')

# %%
df_yahoo['date'] = pd.to_datetime(df_yahoo['date'])
# Out:
# E:\ajeet_data\conda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_yahoo['date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df_yahoo.head()
# Out:
#            date symbol       open      close        low       high      volume
# 713  2010-01-04   YHOO  16.940001  17.100000  16.879999  17.200001  16587400.0
# 1181 2010-01-05   YHOO  17.219999  17.230000  17.000000  17.230000  11718100.0
# 1649 2010-01-06   YHOO  17.170000  17.170000  17.070000  17.299999  16422000.0
# 2117 2010-01-07   YHOO  16.809999  16.700001  16.570000  16.900000  31816300.0
# 2585 2010-01-08   YHOO  16.680000  16.700001  16.620001  16.760000  15470000.0

# %%
df_yahoo.reset_index(drop=True)
# Out:
#            date symbol       open      close        low       high      volume
# 0    2010-01-04   YHOO  16.940001  17.100000  16.879999  17.200001  16587400.0
# 1    2010-01-05   YHOO  17.219999  17.230000  17.000000  17.230000  11718100.0
# 2    2010-01-06   YHOO  17.170000  17.170000  17.070000  17.299999  16422000.0
# 3    2010-01-07   YHOO  16.809999  16.700001  16.570000  16.900000  31816300.0
# 4    2010-01-08   YHOO  16.680000  16.700001  16.620001  16.760000  15470000.0
# 5    2010-01-11   YHOO  16.770000  16.740000  16.480000  16.830000  16181900.0
# 6    2010-01-12   YHOO  16.650000  16.680000  16.600000  16.860001  15672400.0
# 7    2010-01-13   YHOO  16.879999  16.900000  16.650000  16.980000  16955600.0
# 8    2010-01-14   YHOO  16.809999  17.120001  16.799999  17.230000  16715600.0
# 9    2010-01-15   YHOO  17.250000  16.820000  16.750000  17.250000  18415000.0
# 10   2010-01-19   YHOO  16.780001  16.750000  16.639999  16.959999  15182600.0
# ...

# %%
df_yahoo = df_yahoo.set_index('date')

# %%
df_yahoo.shape
# Out:
# (1762, 6)

# %%
df_yahoo.head()
# Out:
#            symbol       open      close        low       high      volume
# date
# 2010-01-04   YHOO  16.940001  17.100000  16.879999  17.200001  16587400.0
# 2010-01-05   YHOO  17.219999  17.230000  17.000000  17.230000  11718100.0
# 2010-01-06   YHOO  17.170000  17.170000  17.070000  17.299999  16422000.0
# 2010-01-07   YHOO  16.809999  16.700001  16.570000  16.900000  31816300.0
# 2010-01-08   YHOO  16.680000  16.700001  16.620001  16.760000  15470000.0

# %%
df_yahoo = df_yahoo.asfreq('b')

# %%
df_yahoo.isna().any()
# Out:
# symbol    True
# open      True
# close     True
# low       True
# high      True
# volume    True
# dtype: bool

# %%
df_yahoo.head()
# Out:
#            symbol       open      close        low       high      volume
# date
# 2010-01-04   YHOO  16.940001  17.100000  16.879999  17.200001  16587400.0
# 2010-01-05   YHOO  17.219999  17.230000  17.000000  17.230000  11718100.0
# 2010-01-06   YHOO  17.170000  17.170000  17.070000  17.299999  16422000.0
# 2010-01-07   YHOO  16.809999  16.700001  16.570000  16.900000  31816300.0
# 2010-01-08   YHOO  16.680000  16.700001  16.620001  16.760000  15470000.0

# %%
df_yahoo.tail(30)
# Out:
#            symbol       open      close        low       high      volume
# date
# 2016-11-21   YHOO  41.439999  41.110001  40.939999  41.480000  11338000.0
# 2016-11-22   YHOO  41.200001  41.009998  40.830002  41.400002   8881200.0
# 2016-11-23   YHOO  40.910000  40.959999  40.549999  40.980000   3634900.0
# 2016-11-24    NaN        NaN        NaN        NaN        NaN         NaN
# 2016-11-25   YHOO  41.080002  40.869999  40.709999  41.080002   2586900.0
# 2016-11-28   YHOO  40.849998  41.450001  40.740002  41.700001   6765800.0
# 2016-11-29   YHOO  41.430000  41.599998  41.119999  41.830002   7246100.0
# 2016-11-30   YHOO  41.619999  41.020000  40.880001  41.669998   7624500.0
# 2016-12-01   YHOO  41.000000  39.630001  39.529999  41.040001  12614600.0
# 2016-12-02   YHOO  39.770000  40.070000  39.580002  40.320000   8568100.0
# 2016-12-05   YHOO  40.020000  40.200001  39.849998  40.389999   4401700.0
# 2016-12-06   YHOO  40.310001  39.970001  39.880001  40.419998   6943800.0
# ...

# %%
df_yahoo.shape
# Out:
# (1825, 6)

# %%
df_yahoo.isnull().sum()
# Out:
# symbol    63
# open      63
# close     63
# low       63
# high      63
# volume    63
# dtype: int64

# %%
null_data =df_yahoo.isnull().any(axis = 1)

# %%
null_data
# Out:
# date
# 2010-01-04    False
# 2010-01-05    False
# 2010-01-06    False
# 2010-01-07    False
# 2010-01-08    False
# 2010-01-11    False
# 2010-01-12    False
# 2010-01-13    False
# 2010-01-14    False
# 2010-01-15    False
# 2010-01-18     True
# 2010-01-19    False
# 2010-01-20    False
# 2010-01-21    False
# 2010-01-22    False
# 2010-01-25    False
# 2010-01-26    False
# 2010-01-27    False
# 2010-01-28    False
# 2010-01-29    False
# 2010-02-01    False
# 2010-02-02    False
# 2010-02-03    False
# 2010-02-04    False
# 2010-02-05    False
# 2010-02-08    False
# 2010-02-09    False
# 2010-02-10    False
# 2010-02-11    False
# 2010-02-12    False
#               ...
# 2016-11-21    False
# 2016-11-22    False
# 2016-11-23    False
# 2016-11-24     True
# 2016-11-25    False
# 2016-11-28    False
# 2016-11-29    False
# 2016-11-30    False
# 2016-12-01    False
# 2016-12-02    False
# 2016-12-05    False
# 2016-12-06    False
# 2016-12-07    False
# 2016-12-08    False
# ...

# %%
null_data.head()
# Out:
# date
# 2010-01-04    False
# 2010-01-05    False
# 2010-01-06    False
# 2010-01-07    False
# 2010-01-08    False
# Freq: B, dtype: bool

# %%
null_dates  = null_data.index.to_list()

# %%
print(null_dates)
# Out:
# [Timestamp('2010-01-04 00:00:00', freq='B'), Timestamp('2010-01-05 00:00:00', freq='B'), Timestamp('2010-01-06 00:00:00', freq='B'), Timestamp('2010-01-07 00:00:00', freq='B'), Timestamp('2010-01-08 00:00:00', freq='B'), Timestamp('2010-01-11 00:00:00', freq='B'), Timestamp('2010-01-12 00:00:00', freq='B'), Timestamp('2010-01-13 00:00:00', freq='B'), Timestamp('2010-01-14 00:00:00', freq='B'), Timestamp('2010-01-15 00:00:00', freq='B'), Timestamp('2010-01-18 00:00:00', freq='B'), Timestamp('2010-01-19 00:00:00', freq='B'), Timestamp('2010-01-20 00:00:00', freq='B'), Timestamp('2010-01-21 00:00:00', freq='B'), Timestamp('2010-01-22 00:00:00', freq='B'), Timestamp('2010-01-25 00:00:00', freq='B'), Timestamp('2010-01-26 00:00:00', freq='B'), Timestamp('2010-01-27 00:00:00', freq='B'), Timestamp('2010-01-28 00:00:00', freq='B'), Timestamp('2010-01-29 00:00:00', freq='B'), Timestamp('2010-02-01 00:00:00', freq='B'), Timestamp('2010-02-02 00:00:00', freq='B'), Timestamp('2010-02-03 00:00:0
# ...

# %%
import calendar
import datetime

holidays = []

for date in null_dates:
    week, day, month, year = date.weekday(), date.day, date.month, date.year
    week_day = calendar.day_name[week]

    if month==1:
        if day==1:
            # New year day
            holidays.append(date)
        elif day==2 and week_day=='Monday':
            # Observed New Year Day
            holidays.append(date)
        elif day>=15 and day<=21 and week_day=='Monday':
            # Martin Luther King, Jr. Day
            holidays.append(date)

    elif month==2:
        # Washington's Birthday
        if day>=15 and day<=21 and week_day=='Monday':
            holidays.append(date)

    elif month==5:
        # Memorial day
        if day>=25 and day<=31 and week_day=='Monday':
            holidays.append(date)

    elif month==7:
        # Independence day
        if day==4:
            holidays.append(date)
        # Observed Independence  Day
        elif day==5 and week_day=='Monday':
            holidays.append(date)
        elif day==3 and week_day=='Friday':
            holidays.append(date)

    elif month == 9:
        # Labour day
        if day>=1 and day<=7 and week_day=='Monday':
            holidays.append(date)

    elif month==11:
        # Thanksgiving Day
        if week_day=='Thursday' and day>=22 and day<=28:
            holidays.append(date)

    elif month==12:
        # Christmas Day
        if day==25:
            holidays.append(date)
        # Observed Christmas Day
        elif day==24 and week_day=='Friday':
            holidays.append(date)
        elif day==26 and week_day=='Monday':
            holidays.append(date)

good_fridays = [ datetime.date(2010,4,2), datetime.date(2011,4,22), datetime.date(2012,4,6), datetime.date(2013,3,29), datetime.date(2014,4,18), datetime.date(2015,4,3), datetime.date(2016,3,25) ]
holidays = holidays + [pd.to_datetime(date) for date in good_fridays]

non_holidays = [x for x in null_dates if x not in holidays]
non_holidays
# Out:
# [Timestamp('2010-01-04 00:00:00', freq='B'),
#  Timestamp('2010-01-05 00:00:00', freq='B'),
#  Timestamp('2010-01-06 00:00:00', freq='B'),
#  Timestamp('2010-01-07 00:00:00', freq='B'),
#  Timestamp('2010-01-08 00:00:00', freq='B'),
#  Timestamp('2010-01-11 00:00:00', freq='B'),
#  Timestamp('2010-01-12 00:00:00', freq='B'),
#  Timestamp('2010-01-13 00:00:00', freq='B'),
#  Timestamp('2010-01-14 00:00:00', freq='B'),
#  Timestamp('2010-01-15 00:00:00', freq='B'),
#  Timestamp('2010-01-19 00:00:00', freq='B'),
#  Timestamp('2010-01-20 00:00:00', freq='B'),
#  Timestamp('2010-01-21 00:00:00', freq='B'),
#  Timestamp('2010-01-22 00:00:00', freq='B'),
#  Timestamp('2010-01-25 00:00:00', freq='B'),
#  Timestamp('2010-01-26 00:00:00', freq='B'),
#  Timestamp('2010-01-27 00:00:00', freq='B'),
#  Timestamp('2010-01-28 00:00:00', freq='B'),
#  Timestamp('2010-01-29 00:00:00', freq='B'),
#  Timestamp('2010-02-01 00:00:00', freq='B'),
#  Timestamp('2010-02-02 00:00:00', freq='B'),
# ...

# %%
df_yahoo.shape
# Out:
# (1825, 6)

# %%
df_yahoo.head()
# Out:
#            symbol       open      close        low       high      volume
# date
# 2010-01-04   YHOO  16.940001  17.100000  16.879999  17.200001  16587400.0
# 2010-01-05   YHOO  17.219999  17.230000  17.000000  17.230000  11718100.0
# 2010-01-06   YHOO  17.170000  17.170000  17.070000  17.299999  16422000.0
# 2010-01-07   YHOO  16.809999  16.700001  16.570000  16.900000  31816300.0
# 2010-01-08   YHOO  16.680000  16.700001  16.620001  16.760000  15470000.0

# %%
modified_df = df_yahoo.drop(holidays)

# %%
modified_df.shape
# Out:
# (1764, 6)

# %%
modified_df.isna().sum()
# Out:
# symbol    2
# open      2
# close     2
# low       2
# high      2
# volume    2
# dtype: int64

# %%
modified_df = modified_df.bfill(axis = 0)

# %%
modified_df.isna().sum()
# Out:
# symbol    0
# open      0
# close     0
# low       0
# high      0
# volume    0
# dtype: int64

# %%
#visualizing the data

def plotter(code):
    global closing_stock
    plt.subplot(211)
    company_close = modified_df[modified_df['symbol']==code]
    company_close = company_close.close.values.astype('float32')
    company_close = company_close.reshape(-1, 1)
    closing_stock = company_close
    plt.xlabel('Time')
    plt.ylabel(code + " close stock prices")
    plt.title('prices Vs Time')
    plt.grid(True)
    plt.plot(company_close , 'b')
    plt.show()

plotter("YHOO")

# %%
# Looking for data variation, using min(), max() 

print(closing_stock.min())
print(closing_stock.max())
# Out:
# 11.09
# 52.37

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0,1))

# %%
stocks = scaler.fit_transform(closing_stock)

# %%
plt.plot(stocks)

# %%
print(stocks.min())
print(stocks.max())
# Out:
# 0.0
# 0.99999994

# %%
n_train = int(len(stocks) * 0.80)
n_remaining = len(stocks) - n_train

n_val = int(n_remaining*0.50)
n_test = n_remaining - n_val 
print("Train samples:",n_train, "Validation Samples:",n_val,"Test Samples:", n_test)
# Out:
# Train samples: 1411 Validation Samples: 176 Test Samples: 177

# %%
train = stocks[0:n_train]
validation = stocks[n_train:n_train + n_val]
test = stocks[n_train + n_val:]

# %%
print(train.shape)
print(validation.shape)
print(test.shape)
# Out:
# (1411, 1)
# (176, 1)
# (177, 1)

# %%
#function for separating the label and target

def create_dataset(data , n_features):
    dataX, dataY = [], []
    for i in range(len(data)-n_features-1):
        a = data[i:(i+n_features), 0]
        dataX.append(a)
        dataY.append(data[i + n_features, 0])
    return np.array(dataX), np.array(dataY)

# %%
train_x, train_y = create_dataset(train,2)
validation_x, validation_y = create_dataset(validation,2)
test_x, test_y = create_dataset(test,2)

print(train_x.shape, train_y.shape, validation_x.shape, validation_y.shape, test_x.shape, test_y.shape)
# Out:
# (1408, 2) (1408,) (173, 2) (173,) (174, 2) (174,)

# %%
# reshaping freature datasets to 3D shape

train_x = train_x.reshape(train_x.shape[0],1,train_x.shape[1])
validation_x = validation_x.reshape(validation_x.shape[0],1,validation_x.shape[1])
test_x = test_x.reshape(test_x.shape[0],1,test_x.shape[1])

print(train_x.shape, train_y.shape, validation_x.shape, validation_y.shape, test_x.shape, test_y.shape)
# Out:
# (1408, 1, 2) (1408,) (173, 1, 2) (173,) (174, 1, 2) (174,)

# %%
import tensorflow as tf
tf.random.set_random_seed(42)

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam

# %%
model = keras.Sequential()

# %%
n_features  =2

# First GRU layer
model.add(layers.GRU(units=100, return_sequences=True, input_shape=(1,n_features), activation='tanh'))
model.add(layers.Dropout(0.2))

# Second GRU layer
model.add(layers.GRU(units=150, return_sequences=True, input_shape=(1,n_features), activation='tanh'))
model.add(layers.Dropout(0.2))

# Third GRU layer
model.add(layers.GRU(units=100, activation='tanh'))
model.add(layers.Dropout(0.2))

# The output layer
model.add(layers.Dense(units=1, kernel_initializer='he_uniform', activation='linear'))
# Out:
# WARNING:tensorflow:From E:\ajeet_data\conda\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
model.compile(loss='mean_squared_error', optimizer=Adam(lr = 0.0005) , metrics = ['mean_squared_error'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# gru (GRU)                    (None, 1, 100)            30900
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 100)            0
# _________________________________________________________________
# gru_1 (GRU)                  (None, 1, 150)            112950
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 150)            0
# _________________________________________________________________
# gru_2 (GRU)                  (None, 100)               75300
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# ...

# %%
history = model.fit(train_x,train_y,epochs=100,batch_size=128, verbose=1, validation_data = (validation_x,validation_y))
# Out:
# Train on 1408 samples, validate on 173 samples
# Epoch 1/100
# 1408/1408 [==============================] - 1s 903us/sample - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 9.9193e-04 - val_mean_squared_error: 9.9193e-04
# Epoch 2/100
# 1408/1408 [==============================] - 0s 185us/sample - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 5.5347e-04 - val_mean_squared_error: 5.5347e-04
# Epoch 3/100
# 1408/1408 [==============================] - 0s 188us/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 9.6145e-04 - val_mean_squared_error: 9.6145e-04
# Epoch 4/100
# 1408/1408 [==============================] - 0s 190us/sample - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 3.9758e-04 - val_mean_squared_error: 3.9758e-04
# Epoch 5/100
# 1408/1408 [==============================] - 0s 200us/sample - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 4.5600e-04 - val_mean_squared_error: 4.5600e-04
# Epoch 6/100
# ...

# %%
# function foe model score
import math

def model_score(model, X_train, y_train, X_val, y_val , X_test, y_test):
    print('Train Score:')
    train_score = model.evaluate(X_train, y_train, verbose=0)
    print("MSE: {:.5f} , RMSE: {:.2f}".format(train_score[0], math.sqrt(train_score[0])))

    print('Validation Score:')
    val_score = model.evaluate(X_val, y_val, verbose=0)
    print("MSE: {:.5f} , RMSE: {:.2f}".format (val_score[0], math.sqrt(val_score[0])))

    print('Test Score:')
    test_score = model.evaluate(X_test, y_test, verbose=0)
    print("MSE: {:.5f} , RMSE: {:.2f}".format (test_score[0], math.sqrt(test_score[0])))

# %%
model_score(model, train_x, train_y ,validation_x, validation_y , test_x, test_y)
# Out:
# Train Score:
# MSE: 0.00020 , RMSE: 0.01
# Validation Score:
# MSE: 0.00036 , RMSE: 0.02
# Test Score:
# MSE: 0.00025 , RMSE: 0.02

# %%
# let's look at the history of the model training
print(history.history.keys())
# Out:
# dict_keys(['loss', 'mean_squared_error', 'val_loss', 'val_mean_squared_error'])

# %%
plt.plot(history.history['loss'])  # plotting train loss
plt.plot(history.history['val_loss'])  # plotting validation loss

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Now let's check the  model predictions

pred = model.predict(test_x)

pred = scaler.inverse_transform(pred)  #inversing the standard scaler transform

# %%
print(pred[:10])
# Out:
# [[37.540928]
#  [37.322628]
#  [37.161736]
#  [37.02236 ]
#  [36.747307]
#  [36.626064]
#  [36.58706 ]
#  [36.245926]
#  [36.05547 ]
#  [36.62396 ]]

# %%
testY_actual = test_y.reshape(test_y.shape[0] , 1)
testY_actual = scaler.inverse_transform(testY_actual)
print(testY_actual[:10])
# Out:
# [[37.23]
#  [37.11]
#  [36.95]
#  [36.59]
#  [36.6 ]
#  [36.53]
#  [36.01]
#  [36.  ]
#  [36.94]
#  [37.23]]

# %%
# prediction and actual value visualization

plt.plot(testY_actual , 'b')
plt.plot(pred , 'r')

plt.xlabel('Time')
plt.ylabel('Stock Prices')
plt.title('Check the performance of the model with time')
plt.legend(['Actual', 'Predicted'], loc='upper left')

plt.grid(True)
plt.show()
